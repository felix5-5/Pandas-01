# %%
import pandas as pd

# %%
df = pd.read_csv("data/ds_salaries.csv")

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
# Grab the median of a column:
df["salary_in_usd"].median()
# Out:
# 101570.0

# %%
# value_counts() method: return how many times a value appears. 
df["company_location"].value_counts().loc[["BR","US"]]
# Out:
# BR      3
# US    355
# Name: company_location, dtype: int64

# %%
# groupby() function: creates a group for each values in that column.
location_grp = df.groupby(["company_location"])

# %%
# get_group() method: allows to access an specific group.
df.groupby(["company_location"]).get_group("BR")
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 133         133       2021               SE              FT
# 205         205       2021               MI              FT
# 271         271       2021               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 133  Computer Vision Engineer   24000             USD          24000
# 205            Data Scientist   69600             BRL          12901
# 271  Computer Vision Engineer  102000             BRL          18907
#
#     employee_residence  remote_ratio company_location company_size
# 133                 BR           100               BR            M
# 205                 BR             0               BR            S
# 271                 BR             0               BR            M

# %%
# Search by an specific column for each group and apply a function: 
location_grp["salary_in_usd"].median()
# Out:
# company_location
# AE    115000.0
# AS     18053.0
# AT     69489.5
# AU     87425.0
# BE     85699.0
# BR     18907.0
# CA     81895.5
# CH     64114.0
# CL     40038.0
# CN     71665.5
# CO     21844.0
# CZ     50937.0
# DE     78015.0
# DK     45896.0
# DZ    100000.0
# EE     32974.0
# ES     48371.5
# FR     56738.0
# GB     78526.0
# GR     49461.0
# HN     20000.0
# HR     45618.0
# HU     35735.0
# IE     71444.0
# IL    119059.0
# IN     22124.0
# IQ    100000.0
# IR      4000.0
# IT     36366.5
# JP     75682.0
# KE      9272.0
# LU     59102.0
# MD     18000.0
# MT     28369.0
# MX     33511.0
# MY     40000.0
# NG     30000.0
# NL     54021.0
# NZ    125000.0
# PK     12000.0
# PL     41093.5
# PT     54217.5
# RO     60000.0
# RU    157500.0
# SG     89294.0
# SI     63831.0
# TR     20171.0
# UA     13400.0
# US    135000.0
# VN      4000.0
# Name: salary_in_usd, dtype: float64

# %%
# Apply a function for specific values inside that group:
location_grp["salary_in_usd"].median().loc[["BR", "US"]]
# Out:
# company_location
# BR     18907.0
# US    135000.0
# Name: salary_in_usd, dtype: float64

# %%
# normalize parameter, show te results in porcentage.  
location_grp["remote_ratio"].value_counts(normalize=True).loc[["BR", "US"]]
# Out:
# company_location  remote_ratio
# BR                0               0.666667
#                   100             0.333333
# US                100             0.749296
#                   0               0.194366
#                   50              0.056338
# Name: remote_ratio, dtype: float64

# %%
# agg() methodo allows to apply more than one function to the operation. 
location_grp["salary_in_usd"].agg(["median", "min", "max"]).loc[["BR", "US"]]
# Out:
#                     median    min     max
# company_location
# BR                 18907.0  12901   24000
# US                135000.0   5679  600000
